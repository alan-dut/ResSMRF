# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xgboost
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
import joblib
model = joblib.load("model.pkl")

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# %%
# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# visualize the first prediction's explanation with a force plot
shap.plots.force(shap_values[10], matplotlib = True)

# %%
# visualize the first prediction's explanation with a force plot
shap.plots.force(shap_values[4])
# Out:
# <div id='i2K6W79XY7JATI93BW4HT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# visualize the first 100 predictions
shap.plots.force(explainer.expected_value,shap_values.values[:100],shap_values.data[:100])
# Out:
# <div id='iATRYX83EI8N44GLMG4FY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# visualize all the training set predictions
shap.plots.force(explainer.expected_value, shap_values.values, shap_values.data)
# Out:
# shap.plots.force is slow for many thousands of rows, try subsampling your data.
# <div id='i2Z7MWN1CUC3B6R90UC5A'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.summary_plot(shap_values)

# %%
shap.plots.bar(shap_values, show=False)
plt.savefig('barplot.svg',format='svg')

# %%
shap.plots.scatter(shap_values[:,"a"], color=shap_values)

# %%
shap.dependence_plot("a", shap_values.values, X)

# %%
shap.dependence_plot("Tg", shap_values.values, X)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot("n", shap_values.values, X)

# %%
shap.dependence_plot("alpha1", shap_values.values, X)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot("Ct", shap_values.values, X)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot("Cy1", shap_values.values, X)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
